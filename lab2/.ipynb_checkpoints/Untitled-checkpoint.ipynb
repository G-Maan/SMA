# %%
import tweepy
from tweepy import OAuthHandler

# %%
consumer_key = 'btcJCKDrw3xxftWgZX0VbwzFE'
consumer_secret = 'fNbyLsESWNYDAjys43rdTAsq1OmZsmeE3oYhkrORKLkth3Yfe6'
access_token = '920256767724019712-RIE4TN6tN5eEOqQKCwngG3oByt5mJaH'
access_secret = 'ESHGh6HTmCRPPG7VR4IakO6uskPkEREloXjYm2K4cCbOD'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth)

# %%
for status in tweepy.Cursor(api.a).items(10):
    # Process a single status
    print(status.text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-5fa8ef6d6291> in <module>()
# ----> 1 for status in tweepy.Cursor(api.a).items(10):
#       2     # Process a single status
#       3     print(status.text)
#
# AttributeError: 'API' object has no attribute 'a'

# %%
rozecka = api.user_timeline(screen_name = 'RozeckaPL', count = 10, include_rts = True)
for status in rozecka:
    print(status.author)
# Out:
# User(_api=<tweepy.api.API object at 0x000001CCE8504898>, _json={'id': 2205387775, 'id_str': '2205387775', 'name': 'M.Stachowiak Różecka', 'screen_name': 'RozeckaPL', 'location': 'Wrocław', 'description': '', 'url': 'https://t.co/FDbYl2ZJpJ', 'entities': {'url': {'urls': [{'url': 'https://t.co/FDbYl2ZJpJ', 'expanded_url': 'http://www.rozecka2018.pl', 'display_url': 'rozecka2018.pl', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2211, 'friends_count': 314, 'listed_count': 12, 'created_at': 'Wed Nov 20 18:30:35 +0000 2013', 'favourites_count': 1130, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 323, 'lang': 'pl', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/them
# ...

# %%
def get_tweets(username, number_of_tweets):
    tweets = api.user_timeline(screen_name=username, count=number_of_tweets, tweet_mode="extended")
    
    tweet_arr = []
    tweets_csv = [[tweet.id_str, tweet.created_at, tweet.full_text] for tweet in tweets]
    for j in tweets_csv:
        tweet_arr.append(j)
    
    with open('%s_tweets.csv' % username, 'wb') as f:
        writer = csv.writer(f)
        writer.writerow(["id", "created_at", "text"])
        writer.writerows(tweets_csv)
    pass

# %%
get_tweets("RozeckaPL", 10)
